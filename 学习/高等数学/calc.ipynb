# %% [markdown]
# 导入相关库

# %%
from sympy import plot
from sympy.abc import x,y,a,b,C
from sympy import *
from sympy import oo

# %%
f = x*E**(-a*x)
f
# Out:
# x*exp(-a*x)

# %%
f.diff(x)
# Out:
# -a*x*exp(-a*x) + exp(-a*x)

# %%
f.integrate(x)
# Out:
# Piecewise(((-a*x - 1)*exp(-a*x)/a**2, Ne(a**2, 0)), (x**2/2, True))

# %%
plot((1/(x**0.5)),(1/x),(1/(x**2)),(x,1,10))
